# %% [markdown]
# # Expert Model

# %%
# %%bash
# git clone https://github.com/sunnytqin/no-distillation.git

# %%
# %%bash
# mkdir -p /kaggle/working/expert_results

# %%
# %%bash
# mkdir -p /kaggle/working/data/tiny-imagenet-200
#
# SRC=tiny-imagenet-200
#
# cp -r /kaggle/input/tiny-imagenet-200/$SRC/* /kaggle/working/data/tiny-imagenet-200/

# %%
# %%bash
# cd /kaggle/working/data/tiny-imagenet-200/val
#
# awk '{print $1, $2}' val_annotations.txt | \
# while read IMG CLS; do
#   mkdir -p images/$CLS
#   mv images/$IMG images/$CLS/
# done

# %%
# %%bash
# export PYTHONPATH=/kaggle/working/no-distillation:/kaggle/working/no-distillation/softlabel:$PYTHONPATH
#
# python /kaggle/working/no-distillation/train_expert/buffer.py \
#   --dataset Tiny \
#   --model ConvNetD4 \
#   --train_epochs 90 \
#   --num_experts 1 \
#   --buffer_path /kaggle/working/no-distillation/results_100_S/checkpoint_epoch_11.pth \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --save_interval 1

# %%
print("\n\n === DONE TRAINING EXPERT === \n\n")

# %% [markdown]
# # Pareto Front
#
# Run student models with full k, for IPC 1,2,5,10,20,50,100,200 and for experts at epochs 20, 40, 60, 90.
#
# Must run in parallel as each one takes 8 hours.

# %%
# %%bash
# cd /kaggle/working/no-distillation
#
# cp -r softlabel/indices .
#
# ls -R indices

# %%
# %%bash
# cd /kaggle/working/no-distillation
#
# mkdir -p results_100_S/Tiny/imagenette/ConvNetD4
#
# cp \
#   results_100_S/checkpoint_epoch_11.pth/Tiny/ConvNetD4/replay_buffer_0.pt \
#   results_100_S/Tiny/imagenette/ConvNetD4/replay_buffer_1.pt
#
# cp \
#   results_100_S/checkpoint_epoch_11.pth/Tiny/ConvNetD4/replay_buffer_0.pt \
#   results_100_S/checkpoint_epoch_11.pth/Tiny/ConvNetD4/replay_buffer_1.pt

# %% [markdown]
# epoch 20
# ipc 1

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 1 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 20 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 20 ipc 2

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 2 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 20 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 20 ipc 5

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 5 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 20 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 20 ipc 10

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 10 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 20 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 20 ipc 50

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 50 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 20 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 20 ipc 100

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 100 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 20 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 20 ipc 200

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 200 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 20 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 1

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 1 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 2

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 2 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 5

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 5 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 10

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 10 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 20

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 20 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 50

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 50 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 100

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 100 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 40 ipc 200

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 200 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 40 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 1

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 1 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 2

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 2 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 5

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 5 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 10

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 10 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 20

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 20 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 50

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 50 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 100

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 100 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 60 ipc 200

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 200 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 60 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 1

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 1 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 2

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 2 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 5

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 5 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 10

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 10 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 20

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 20 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 50

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 50 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 100

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 100 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000

# %% [markdown]
# epoch 90 ipc 200

# %%
# %%bash
# cd /kaggle/working/no-distillation
# export PYTHONPATH=$(pwd):$(pwd)/train_expert:$PYTHONPATH
#
# python softlabel/nodistill.py \
#   --dataset Tiny \
#   --ipc 200 \
#   --expt_type nothing \
#   --teacher_label \
#   --max_expert_epoch 90 \
#   --lr_net 1e-2 \
#   --expert_path /kaggle/working/no-distillation/results_100_S \
#   --data_path /kaggle/working/data/tiny-imagenet-200 \
#   --student_model ConvNetD4 \
#   --teacher_model ConvNetD4 \
#   --epoch_eval_train 3000
